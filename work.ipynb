# %%
import pandas as pd
import numpy as np

# %%
# !pip install wandb
# Out:
# Requirement already satisfied: wandb in /opt/anaconda3/lib/python3.13/site-packages (0.26.0)
# Requirement already satisfied: click>=8.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from wandb) (8.1.8)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from wandb) (3.1.43)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from wandb) (24.2)
# Requirement already satisfied: platformdirs in /opt/anaconda3/lib/python3.13/site-packages (from wandb) (4.3.7)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<8,>4.21.0 in /opt/anaconda3/lib/python3.13/site-packages (from wandb) (5.29.3)
# Requirement already satisfied: pydantic<3 in /opt/anaconda3/lib/python3.13/site-packages (from wandb) (2.10.3)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.13/site-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from wandb) (2.58.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /opt/anaconda3/lib/python3.13/site-packages (from wandb) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3->wandb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3->wandb) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.0.0->wandb) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.0.0->wandb) (2025.10.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (4.0.0)

# %%
import wandb
wandb.login()
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /Users/md.shorifulislamfahim/.netrc.
# wandb: Currently logged in as: fahim2443 (fahim2443-the-velox-studio) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
wandb.init(project="Ames-Iowa-house-price-prediction")
# Out:
# Tracking run with wandb version 0.26.0
# Run data is saved locally in <code>/Users/md.shorifulislamfahim/Developer/Kaggle/home-data-for-ml-course/wandb/run-20260531_202856-9tao9xod</code>
# Syncing run <strong><a href='https://wandb.ai/fahim2443-the-velox-studio/Ames-Iowa-house-price-prediction/runs/9tao9xod' target="_blank">copper-shape-5</a></strong> to <a href='https://wandb.ai/fahim2443-the-velox-studio/Ames-Iowa-house-price-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/fahim2443-the-velox-studio/Ames-Iowa-house-price-prediction' target="_blank">https://wandb.ai/fahim2443-the-velox-studio/Ames-Iowa-house-price-prediction</a>
#  View run at <a href='https://wandb.ai/fahim2443-the-velox-studio/Ames-Iowa-house-price-prediction/runs/9tao9xod' target="_blank">https://wandb.ai/fahim2443-the-velox-studio/Ames-Iowa-house-price-prediction/runs/9tao9xod</a>
# &lt;wandb.sdk.wandb_run.Run object at 0x16259dfd0&gt;

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
print ("Train data shape: ", train.shape)
print ("Test data shape: ", test.shape)
# Out:
# Train data shape:  (1460, 81)
# Test data shape:  (1459, 80)

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
import matplotlib.pyplot as plt
plt.style.use(style = 'ggplot')
plt.rcParams['figure.figsize'] = (10,6)

# %%
train.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
print("Skew is: ", train.SalePrice.skew())
plt.hist(train.SalePrice, color='blue')
plt.show()
# Out:
# Skew is:  1.8828757597682129

# %%
target=np.log(train.SalePrice)
print("Skew is: ", target.skew())
plt.hist(target, color='red')
plt.show()
# Out:
# Skew is:  0.12133506220520406

# %%
numeric_features = train.select_dtypes(include=[np.number])
numeric_features.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SalePrice          int64
# dtype: object

# %%
corr = numeric_features.corr()
print(corr['SalePrice'].sort_values(ascending=False)[:5], '\n')
print(corr['SalePrice'].sort_values(ascending=False)[-5:])
# Out:
# SalePrice      1.000000
# OverallQual    0.790982
# GrLivArea      0.708624
# GarageCars     0.640409
# GarageArea     0.623431
# Name: SalePrice, dtype: float64
#
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# EnclosedPorch   -0.128578
# KitchenAbvGr    -0.135907
# Name: SalePrice, dtype: float64

# %%
train.OverallQual.unique()
# Out:
# array([ 7,  6,  8,  5,  9,  4, 10,  3,  1,  2])

# %%
quality_pivot = train.pivot_table(index='OverallQual', values='SalePrice', aggfunc=np.median)
quality_pivot
# Out:
# /var/folders/bn/ydsl55b55bj1zvt7lh6b3m880000gn/T/ipykernel_59976/3082342935.py:1: FutureWarning: The provided callable <function median at 0x106999940> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   quality_pivot = train.pivot_table(index='OverallQual', values='SalePrice', aggfunc=np.median)
#              SalePrice
# OverallQual
# 1              50150.0
# 2              60000.0
# 3              86250.0
# 4             108000.0
# 5             133000.0
# 6             160000.0
# 7             200141.0
# 8             269750.0
# 9             345000.0
# 10            432390.0

# %%
quality_pivot.plot(kind='bar', color='purple')
plt.xlabel('Overall Quality')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()

# %%
plt.scatter(x=train.GrLivArea, y=target, alpha=0.5)
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')
plt.show()

# %%
plt.scatter(x=train.GarageArea, y=target, alpha=0.5)
plt.xlabel('GarageArea')
plt.ylabel('SalePrice')
plt.show()

# %%
train = train[train['GarageArea'] < 1200]
plt.scatter(x=train.GarageArea, y=np.log(train.SalePrice), alpha=0.5)
plt.xlabel('GarageArea')
plt.ylabel('SalePrice')
plt.show()

# %%
nulls = pd.DataFrame(train.isnull().sum().sort_values(ascending=False)[:25])
nulls.columns = ['Null Count']
nulls.index.name = 'Feature'
nulls
# Out:
#               Null Count
# Feature
# PoolQC              1449
# MiscFeature         1402
# Alley               1364
# Fence               1174
# MasVnrType           871
# FireplaceQu          689
# LotFrontage          258
# GarageYrBlt           81
# GarageCond            81
# GarageType            81
# GarageFinish          81
# GarageQual            81
# BsmtFinType2          38
# BsmtExposure          38
# BsmtQual              37
# BsmtCond              37
# BsmtFinType1          37
# MasVnrArea             8
# Electrical             1
# Id                     0
# Functional             0
# Fireplaces             0
# KitchenQual            0
# KitchenAbvGr           0
# BedroomAbvGr           0

# %%
print("Unique Values are:", train.MiscFeature.unique())
# Out:
# Unique Values are: [nan 'Shed' 'Gar2' 'Othr' 'TenC']

# %%
categoricals = train.select_dtypes(exclude=[np.number])
categoricals.describe()
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1455   1455    91     1455        1455      1455      1455
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1147   1450    50      921        1309      1454      1048
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1455         1455       1455  ...       1374         1374
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1378          225       1257  ...        867          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1374       1374       1455      6    281          53     1455
# unique          5          5          3      3      4           4        9
# top            TA         TA          Y     Ex  MnPrv        Shed       WD
# freq         1306       1321       1335      2    157          48     1266
#
#        SaleCondition
# count           1455
# unique             6
# top           Normal
# freq            1196
#
# [4 rows x 43 columns]

# %%
print("Origina: \n")
print(train.Street.value_counts(), "\n")
# Out:
# Origina:
#
# Street
# Pave    1450
# Grvl       5
# Name: count, dtype: int64

# %%
train['Enc_Street'] = pd.get_dummies(train.Street, drop_first=True)
test['Enc_Street'] = pd.get_dummies(test.Street, drop_first=True)

# %%
print('Encoded: \n')
print(train.Enc_Street.value_counts())
# Out:
# Encoded:
#
# Enc_Street
# True     1450
# False       5
# Name: count, dtype: int64

# %%
condition_pivot = train.pivot_table(index='SaleCondition', values='SalePrice', aggfunc=np.median)
condition_pivot.plot(kind='bar', color='blue')
plt.xlabel('Sale Condition')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()
# Out:
# /var/folders/bn/ydsl55b55bj1zvt7lh6b3m880000gn/T/ipykernel_59976/861873413.py:1: FutureWarning: The provided callable <function median at 0x106999940> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   condition_pivot = train.pivot_table(index='SaleCondition', values='SalePrice', aggfunc=np.median)

# %%
def encode(x):
    return 1 if x == 'Partial' else 0
train['Enc_Condition'] = train.SaleCondition.apply(encode)
test['Enc_Condition'] = test.SaleCondition.apply(encode)

# %%
condition_pivot = train.pivot_table(index='Enc_Condition', values='SalePrice', aggfunc=np.median)
condition_pivot.plot(kind='bar', color='blue')
plt.xlabel('Encoded Sale Condition')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()
# Out:
# /var/folders/bn/ydsl55b55bj1zvt7lh6b3m880000gn/T/ipykernel_59976/3231463984.py:1: FutureWarning: The provided callable <function median at 0x106999940> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   condition_pivot = train.pivot_table(index='Enc_Condition', values='SalePrice', aggfunc=np.median)

# %%
data = train.select_dtypes(include=[np.number]).interpolate().dropna()

# %%
sum(data.isnull().sum() != 0)
# Out:
# 0

# %%
y = np.log(train.SalePrice)
X = data.drop(['SalePrice', 'Id'], axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
                          X, y, random_state=42, test_size=.33)

# %%
from sklearn import linear_model
lr = linear_model.LinearRegression()

# %%
model = lr.fit(X_train, y_train)

# %%
print ("R^2 is: \n", model.score(X_test, y_test))
# Out:
# R^2 is:
#  0.8883509099666321

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
print ('RMSE is: \n', mean_squared_error(y_test, predictions))
# Out:
# RMSE is:
#  0.01782532786310264

# %%
actual_values = y_test
plt.scatter(predictions, actual_values, alpha=.7,
            color='b') #alpha helps to show overlapping data
plt.xlabel('Predicted Price')
plt.ylabel('Actual Price')
plt.title('Linear Regression Model')
plt.show()

# %%
for i in range(-2, 3):
    alpha = 10**i
    rm = linear_model.Ridge(alpha=alpha)
    ridge_model = rm.fit(X_train, y_train)
    preds_ridge = ridge_model.predict(X_test)

    plt.figure()
    plt.scatter(preds_ridge, actual_values, alpha=.75, color='b')
    plt.xlabel('Predicted Price')
    plt.ylabel('Actual Price')
    plt.title(f'Ridge Regularization with alpha = {alpha}')

    r2 = ridge_model.score(X_test, y_test)
    rmse = mean_squared_error(y_test, preds_ridge)
    overlay = f'R^2: {r2:.3f}\\nRMSE: {rmse:.3f}'

    plt.gca().annotate(
        overlay,
        xy=(0.05, 0.95),
        xycoords='axes fraction',
        fontsize=12,
        ha='left',
        va='top',
        bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.3)
    )
    plt.show()

# %%
submission = pd.DataFrame()
submission['Id'] = test.Id

# %%
feats = test.select_dtypes(
        include=[np.number]).drop(['Id'], axis=1).interpolate()

# %%
predictions = model.predict(feats)

# %%
final_predictions = np.exp(predictions)

# %%
print ("Original predictions are: \n", predictions[:5], "\n")
print ("Final predictions are: \n", final_predictions[:5])
# Out:
# Original predictions are:
#  [11.76015115 11.70293438 12.07323941 12.20563751 12.10732981]
#
# Final predictions are:
#  [128046.80582341 120926.03777844 175122.21974384 199912.99134382
#  181195.13262268]

# %%
submission['SalePrice'] = final_predictions
submission.head()
# Out:
#      Id      SalePrice
# 0  1461  128046.805823
# 1  1462  120926.037778
# 2  1463  175122.219744
# 3  1464  199912.991344
# 4  1465  181195.132623

# %%
submission.to_csv('submission.csv', index=False)
